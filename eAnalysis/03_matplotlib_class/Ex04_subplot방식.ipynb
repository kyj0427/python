# %%
import numpy as np
import matplotlib.pyplot as plt

""" 1.  figure(그림틀=공간?)을 만들고 거기에 subplot을 추가 하는 방식 """

# plt.figure()
# plt.plot(np.random.randn(100))
# plt.plot(np.random.randn(200).cumsum())
# plt.show()

fig = plt.figure(figsize=(12,3)) #영역 확보후 변수에 담기
ax1 = fig.add_subplot(1,2,1)  #부분 그래프를 추가하여 ax1 변수에 담기
ax2 = fig.add_subplot(1,2,2)  

ax1.plot(np.random.randn(100))
ax2.plot(np.random.randn(200).cumsum())

# %%
""" 2. figure로 공간을 만들고 파이플롯(pyplot)의 subplot()으로 각각의 패널 지정 """
fig = plt.figure(figsize=(12,3)) #영역 확보후 변수에 담기
ax1 = plt.subplot(1,2,1)  #부분 그래프를 추가하여 ax1 변수에 담기
ax2 = plt.subplot(1,2,2)  

ax1.plot(np.random.randn(100))
ax2.plot(np.random.randn(200).cumsum())

# %%
""" 3. 간단하게 ax 객체를 이용하기 """
fig, ax = plt.subplots(1,2)
ax[0].plot(np.random.randn(100))
ax[1].plot(np.random.randn(200).cumsum())

# %% [markdown]
# ## 서브플롯 개념

# %%
plt.figure(figsize=(16,8))

plt.subplot(2,2,1) # (221) 콤마가 없어도 읽을수있어야한
plt.subplot(2,2,2)
plt.subplot(2,1,2)

plt.show()

# %%
plt.figure(figsize=(16,8))

plt.subplot(211) 
plt.subplot(223)
plt.subplot(224)

plt.show()

# %%
plt.figure(figsize=(16,8))

plt.subplot(2,3,(1,2)) 
plt.subplot(2,3,3)
plt.subplot(2,1,2)

plt.show()
